# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
wild_bunch_ground_truth = pd.read_csv("wild_bunch_2.csv")

# %%
wild_bunch_ground_truth
# Out:
#         Start       End Action
# 0    00:00:00  00:00:14    NaN
# 1    00:00:14  00:00:26    NaN
# 2    00:00:26  00:00:35    NaN
# 3    00:00:35  00:00:39    NaN
# 4    00:00:39  00:00:41    NaN
# ..        ...       ...    ...
# 143  00:09:40  00:09:43    NaN
# 144  00:09:43  00:09:48    NaN
# 145  00:09:48  00:09:55    NaN
# 146  00:09:55  00:09:57    NaN
# 147  00:09:57  00:10:01    NaN
#
# [148 rows x 3 columns]

# %%
wild_bunch_ground_truth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Start   148 non-null    object
#  1   End     148 non-null    object
#  2   Action  5 non-null      object
# dtypes: object(3)
# memory usage: 3.6+ KB

# %%
wild_bunch_ground_truth.describe()
# Out:
#            Start       End Action
# count        148       148      5
# unique       148       148      1
# top     00:00:00  00:00:14  Fight
# freq           1         1      5

# %%
wild_bunch_ground_truth["Start"] = pd.to_timedelta(wild_bunch_ground_truth["Start"]).dt.total_seconds()

# %%
wild_bunch_ground_truth["End"] = pd.to_timedelta(wild_bunch_ground_truth["End"]).dt.total_seconds()

# %%
wild_bunch_ground_truth
# Out:
#      Start    End Action
# 0      0.0   14.0    NaN
# 1     14.0   26.0    NaN
# 2     26.0   35.0    NaN
# 3     35.0   39.0    NaN
# 4     39.0   41.0    NaN
# ..     ...    ...    ...
# 143  580.0  583.0    NaN
# 144  583.0  588.0    NaN
# 145  588.0  595.0    NaN
# 146  595.0  597.0    NaN
# 147  597.0  601.0    NaN
#
# [148 rows x 3 columns]

# %%
wild_bunch_siglip_0_8 = pd.read_csv("The Wild Bunch (1969)-0_8.csv")

# %%
wild_bunch_siglip_0_8
# Out:
#        Start     End    Start Time      End Time
# 0          0     877  00:00:00.000  00:00:14.631
# 1        878    1597  00:00:14.648  00:00:26.643
# 2       1598    2152  00:00:26.660  00:00:35.903
# 3       2153    2396  00:00:35.919  00:00:39.973
# 4       2397    2524  00:00:39.990  00:00:42.109
# ...      ...     ...           ...           ...
# 1818  510255  510566  02:21:52.763  02:21:57.951
# 1819  510567  510934  02:21:57.968  02:22:04.091
# 1820  510935  512354  02:22:04.107  02:22:27.781
# 1821  512355  512451  02:22:27.798  02:22:29.399
# 1822  512452  512606  02:22:29.416  02:22:31.985
#
# [1823 rows x 4 columns]

# %%
wild_bunch_siglip_0_8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1823 entries, 0 to 1822
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Start       1823 non-null   int64
#  1   End         1823 non-null   int64
#  2   Start Time  1823 non-null   object
#  3   End Time    1823 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 57.1+ KB

# %%
wild_bunch_siglip_0_8["Start Time"] = pd.to_timedelta(wild_bunch_siglip_0_8["Start Time"]).dt.total_seconds()

# %%
wild_bunch_siglip_0_8["End Time"] = pd.to_timedelta(wild_bunch_siglip_0_8["End Time"]).dt.total_seconds()

# %%
wild_bunch_siglip_0_8
# Out:
#        Start     End  Start Time  End Time
# 0          0     877       0.000    14.631
# 1        878    1597      14.648    26.643
# 2       1598    2152      26.660    35.903
# 3       2153    2396      35.919    39.973
# 4       2397    2524      39.990    42.109
# ...      ...     ...         ...       ...
# 1818  510255  510566    8512.763  8517.951
# 1819  510567  510934    8517.968  8524.091
# 1820  510935  512354    8524.107  8547.781
# 1821  512355  512451    8547.798  8549.399
# 1822  512452  512606    8549.416  8551.985
#
# [1823 rows x 4 columns]

# %%
wild_bunch_siglip_0_7 = pd.read_csv("The Wild Bunch (1969)-1-0_7.csv")

# %%
wild_bunch_siglip_0_7
# Out:
#       Start     End    Start Time      End Time
# 0         0    2152  00:00:00.000  00:00:35.903
# 1      2153    3149  00:00:35.919  00:00:52.536
# 2      3150    3284  00:00:52.553  00:00:54.788
# 3      3285    3739  00:00:54.805  00:01:02.379
# 4      3740    4547  00:01:02.396  00:01:15.859
# ..      ...     ...           ...           ...
# 564  506777  507586  02:20:54.738  02:21:08.235
# 565  507587  508844  02:21:08.252  02:21:29.223
# 566  508845  509979  02:21:29.239  02:21:48.158
# 567  509980  512451  02:21:48.175  02:22:29.399
# 568  512452  512606  02:22:29.416  02:22:31.985
#
# [569 rows x 4 columns]

# %%
wild_bunch_siglip_0_7["Start Time"] = pd.to_timedelta(wild_bunch_siglip_0_7["Start Time"]).dt.total_seconds()

# %%
wild_bunch_siglip_0_7["End Time"] = pd.to_timedelta(wild_bunch_siglip_0_7["End Time"]).dt.total_seconds()

# %%
wild_bunch_siglip_0_75 = pd.read_csv("The Wild Bunch (1969)-2-0_75.csv")

# %%
wild_bunch_siglip_0_75["Start Time"] = pd.to_timedelta(wild_bunch_siglip_0_75["Start Time"]).dt.total_seconds()

# %%
wild_bunch_siglip_0_75["End Time"] = pd.to_timedelta(wild_bunch_siglip_0_75["End Time"]).dt.total_seconds()

# %%
wild_bunch_siglip_0_75
# Out:
#        Start     End  Start Time  End Time
# 0          0      60       0.000     1.001
# 1         61     877       1.018    14.631
# 2        878     952      14.648    15.883
# 3        953    1597      15.899    26.643
# 4       1598    2152      26.660    35.903
# ...      ...     ...         ...       ...
# 2426  511790  512034    8538.372  8542.442
# 2427  512035  512144    8542.459  8544.278
# 2428  512145  512354    8544.294  8547.781
# 2429  512355  512451    8547.798  8549.399
# 2430  512452  512606    8549.416  8551.985
#
# [2431 rows x 4 columns]

# %%
wild_bunch_siglip_0_85 = pd.read_csv("The Wild Bunch (1969)-3-0_85.csv")

# %%
wild_bunch_siglip_0_85
# Out:
#        Start     End    Start Time      End Time
# 0          0    2152  00:00:00.000  00:00:35.903
# 1       2153    2396  00:00:35.919  00:00:39.973
# 2       2397    2524  00:00:39.990  00:00:42.109
# 3       2525    3149  00:00:42.125  00:00:52.536
# 4       3150    3284  00:00:52.553  00:00:54.788
# ...      ...     ...           ...           ...
# 1143  509232  509979  02:21:35.696  02:21:48.158
# 1144  509980  510254  02:21:48.175  02:21:52.746
# 1145  510255  510566  02:21:52.763  02:21:57.951
# 1146  510567  512451  02:21:57.968  02:22:29.399
# 1147  512452  512606  02:22:29.416  02:22:31.985
#
# [1148 rows x 4 columns]

# %%
wild_bunch_siglip_0_85["Start Time"] = pd.to_timedelta(wild_bunch_siglip_0_85["Start Time"]).dt.total_seconds()

# %%
wild_bunch_siglip_0_85["End Time"] = pd.to_timedelta(wild_bunch_siglip_0_85["End Time"]).dt.total_seconds()

# %%
wild_bunch_siglip_0_85
# Out:
#        Start     End  Start Time  End Time
# 0          0    2152       0.000    35.903
# 1       2153    2396      35.919    39.973
# 2       2397    2524      39.990    42.109
# 3       2525    3149      42.125    52.536
# 4       3150    3284      52.553    54.788
# ...      ...     ...         ...       ...
# 1143  509232  509979    8495.696  8508.158
# 1144  509980  510254    8508.175  8512.746
# 1145  510255  510566    8512.763  8517.951
# 1146  510567  512451    8517.968  8549.399
# 1147  512452  512606    8549.416  8551.985
#
# [1148 rows x 4 columns]

# %%
wild_bunch_siglip_0_7 = wild_bunch_siglip_0_7[:len(wild_bunch_ground_truth)]

# %%
wild_bunch_siglip_0_75 = wild_bunch_siglip_0_75[:len(wild_bunch_ground_truth)]

# %%
wild_bunch_siglip_0_8 = wild_bunch_siglip_0_8[:len(wild_bunch_ground_truth)]

# %%
wild_bunch_siglip_0_85 = wild_bunch_siglip_0_85[:len(wild_bunch_ground_truth)]

# %%
wild_bunch_siglip_0_7 = wild_bunch_siglip_0_7[["Start Time","End Time"]]
wild_bunch_siglip_0_75 = wild_bunch_siglip_0_75[["Start Time","End Time"]]
wild_bunch_siglip_0_8 = wild_bunch_siglip_0_8[["Start Time","End Time"]]
wild_bunch_siglip_0_85 = wild_bunch_siglip_0_85[["Start Time","End Time"]]

# %%
compare_1_df = pd.concat([wild_bunch_ground_truth,wild_bunch_siglip_0_7], axis=1)
compare_2_df = pd.concat([wild_bunch_ground_truth,wild_bunch_siglip_0_75], axis=1)
compare_3_df = pd.concat([wild_bunch_ground_truth,wild_bunch_siglip_0_8], axis=1)
compare_4_df = pd.concat([wild_bunch_ground_truth,wild_bunch_siglip_0_85], axis=1)

# %%
compare_1_df["Start Error 0.7"] = (compare_1_df["Start"] - compare_1_df["Start Time"]).abs()
compare_1_df["End Error 0.7"] = (compare_1_df["End"] - compare_1_df["End Time"]).abs()
compare_2_df["Start Error 0.75"] = (compare_2_df["Start"] - compare_2_df["Start Time"]).abs()
compare_2_df["End Error 0.75"] = (compare_2_df["End"] - compare_2_df["End Time"]).abs()
compare_3_df["Start Error 0.8"] = (compare_3_df["Start"] - compare_3_df["Start Time"]).abs()
compare_3_df["End Error 0.8"] = (compare_3_df["End"] - compare_3_df["End Time"]).abs()
compare_4_df["Start Error 0.85"] = (compare_4_df["Start"] - compare_4_df["Start Time"]).abs()
compare_4_df["End Error 0.85"] = (compare_4_df["End"] - compare_4_df["End Time"]).abs()

# %%
compare_1_df
# Out:
#      Start    End Action  Start Time  End Time  Start Error 0.7  End Error 0.7
# 0      0.0   14.0    NaN       0.000    35.903            0.000         21.903
# 1     14.0   26.0    NaN      35.919    52.536           21.919         26.536
# 2     26.0   35.0    NaN      52.553    54.788           26.553         19.788
# 3     35.0   39.0    NaN      54.805    62.379           19.805         23.379
# 4     39.0   41.0    NaN      62.396    75.859           23.396         34.859
# ..     ...    ...    ...         ...       ...              ...            ...
# 143  580.0  583.0    NaN    2027.628  2028.495         1447.628       1445.495
# 144  583.0  588.0    NaN    2028.512  2030.080         1445.512       1442.080
# 145  588.0  595.0    NaN    2030.097  2037.120         1442.097       1442.120
# 146  595.0  597.0    NaN    2037.137  2039.957         1442.137       1442.957
# 147  597.0  601.0    NaN    2039.973  2041.291         1442.973       1440.291
#
# [148 rows x 7 columns]

# %%
compare_1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Start            148 non-null    float64
#  1   End              148 non-null    float64
#  2   Action           5 non-null      object
#  3   Start Time       148 non-null    float64
#  4   End Time         148 non-null    float64
#  5   Start Error 0.7  148 non-null    float64
#  6   End Error 0.7    148 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.2+ KB

# %%
compare_1_df.describe()
# Out:
#             Start         End   Start Time     End Time  Start Error 0.7  \
# count  148.000000  148.000000   148.000000   148.000000       148.000000
# mean   325.689189  329.695946   680.805358   694.581304       355.116169
# std    169.727507  169.077314   459.873182   469.819504       317.122360
# min      0.000000   14.000000     0.000000    35.903000         0.000000
# 25%    190.750000  196.000000   382.115250   393.264000       195.440500
# 50%    343.000000  347.000000   684.852000   697.072000       340.131500
# 75%    476.500000  478.750000   822.889250   823.890250       360.004500
# max    597.000000  601.000000  2039.973000  2041.291000      1453.460000
#
#        End Error 0.7
# count     148.000000
# mean      364.885358
# std       328.051658
# min        19.788000
# 25%       197.304000
# 50%       340.215000
# 75%       361.390250
# max      1453.443000

# %%
compare_2_df.describe()
# Out:
#             Start         End  Start Time    End Time  Start Error 0.75  \
# count  148.000000  148.000000  148.000000  148.000000        148.000000
# mean   325.689189  329.695946  292.977365  296.534493         32.711824
# std    169.727507  169.077314  159.056830  158.369905         14.381383
# min      0.000000   14.000000    0.000000    1.001000          0.000000
# 25%    190.750000  196.000000  144.198000  147.522500         24.915000
# 50%    343.000000  347.000000  302.744000  305.314000         33.202000
# 75%    476.500000  478.750000  442.008750  445.525000         39.675750
# max    597.000000  601.000000  523.841000  528.912000         73.159000
#
#        End Error 0.75
# count      148.000000
# mean        33.161453
# std         14.493888
# min          1.464000
# 25%         25.118750
# 50%         33.412500
# 75%         40.212500
# max         73.176000

# %%
compare_3_df.describe()
# Out:
#             Start         End  Start Time    End Time  Start Error 0.8  \
# count  148.000000  148.000000  148.000000  148.000000       148.000000
# mean   325.689189  329.695946  353.562257  357.948622        31.770541
# std    169.727507  169.077314  200.083928  199.419546        30.400872
# min      0.000000   14.000000    0.000000   14.631000         0.000000
# 25%    190.750000  196.000000  188.496500  197.005500         7.351500
# 50%    343.000000  347.000000  355.505500  366.975500        20.624000
# 75%    476.500000  478.750000  517.480250  530.330250        43.597000
# max    597.000000  601.000000  650.067000  651.635000       109.241000
#
#        End Error 0.8
# count     148.000000
# mean       32.142311
# std        30.312441
# min         0.134000
# 25%         7.414000
# 50%        23.144000
# 75%        50.704250
# max       109.224000

# %%
compare_4_df.describe()
# Out:
#             Start         End  Start Time    End Time  Start Error 0.85  \
# count  148.000000  148.000000  148.000000  148.000000        148.000000
# mean   325.689189  329.695946  435.645574  440.658676        110.212115
# std    169.727507  169.077314  239.932060  238.535908         73.865037
# min      0.000000   14.000000    0.000000   35.903000          0.000000
# 25%    190.750000  196.000000  215.499000  222.201500         28.517000
# 50%    343.000000  347.000000  481.298000  485.160000        136.677500
# 75%    476.500000  478.750000  656.077250  656.419000        179.492000
# max    597.000000  601.000000  742.943000  744.394000        205.241000
#
#        End Error 0.85
# count      148.000000
# mean       111.219378
# std         73.350054
# min          0.242000
# 25%         28.722750
# 50%        138.160000
# 75%        179.475000
# max        205.224000

# %%
compare_1_df = compare_1_df.drop(["Start","End","Action","Start Time","End Time"], axis=1)
compare_2_df = compare_2_df.drop(["Start","End","Action","Start Time","End Time"], axis=1)
compare_3_df = compare_3_df.drop(["Start","End","Action","Start Time","End Time"], axis=1)
compare_4_df = compare_4_df.drop(["Start","End","Action","Start Time","End Time"], axis=1)

# %%
merged_results = pd.concat([compare_1_df, compare_2_df, compare_3_df, compare_4_df], axis=1)

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /opt/tljh/user/lib/python3.9/site-packages/matplotlib-3.7.0rc1-py3.9-linux-x86_64.egg (3.7.0rc1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.local/lib/python3.9/site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in ./.local/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.local/lib/python3.9/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./.local/lib/python3.9/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in ./.local/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib) (21.2)
# Requirement already satisfied: pillow>=6.2.0 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/tljh/user/lib/python3.9/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.local/lib/python3.9/site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: zipp>=3.1.0 in /opt/tljh/user/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Requirement already satisfied: six>=1.5 in /opt/tljh/user/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
merged_results[["Start Error 0.7","Start Error 0.75","Start Error 0.8","Start Error 0.85"]].plot(kind="box")
plt.savefig("analysis_1.png")

# %%
merged_results[["Start Error 0.7","Start Error 0.75","Start Error 0.8","Start Error 0.85"]].plot(kind="line")
plt.savefig("analysis_2.png")

# %%
merged_results[["End Error 0.7","End Error 0.75","End Error 0.8","End Error 0.85"]].plot(kind="box")
plt.savefig("analysis_3.png")

# %%
merged_results[["End Error 0.7","End Error 0.75","End Error 0.8","End Error 0.85"]].plot(kind="line")
plt.savefig("analysis_4.png")

# %%
merged_results.describe()
# Out:
#        Start Error 0.7  End Error 0.7  Start Error 0.75  End Error 0.75  \
# count       148.000000     148.000000        148.000000      148.000000
# mean        355.116169     364.885358         32.711824       33.161453
# std         317.122360     328.051658         14.381383       14.493888
# min           0.000000      19.788000          0.000000        1.464000
# 25%         195.440500     197.304000         24.915000       25.118750
# 50%         340.131500     340.215000         33.202000       33.412500
# 75%         360.004500     361.390250         39.675750       40.212500
# max        1453.460000    1453.443000         73.159000       73.176000
#
#        Start Error 0.8  End Error 0.8  Start Error 0.85  End Error 0.85
# count       148.000000     148.000000        148.000000      148.000000
# mean         31.770541      32.142311        110.212115      111.219378
# std          30.400872      30.312441         73.865037       73.350054
# min           0.000000       0.134000          0.000000        0.242000
# 25%           7.351500       7.414000         28.517000       28.722750
# 50%          20.624000      23.144000        136.677500      138.160000
# 75%          43.597000      50.704250        179.492000      179.475000
# max         109.241000     109.224000        205.241000      205.224000
